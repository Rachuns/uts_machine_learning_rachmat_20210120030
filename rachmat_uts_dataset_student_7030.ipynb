# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path_='/content/drive/MyDrive/Machine Learning/student.csv'
dataset=pd.read_csv(path_, sep=';')
dataset
# Out:
#            Timestamp  Kindly Rate your Sleep Quality ??  \
# 0   27/10/2023 21:54                                  3
# 1   28/10/2023 12:24                                  4
# 2   28/10/2023 12:24                                  2
# 3   28/10/2023 12:26                                  3
# 4   28/10/2023 12:26                                  2
# 5   28/10/2023 12:31                                  3
# 6   28/10/2023 12:34                                  3
# 7   28/10/2023 12:35                                  4
# 8   28/10/2023 12:36                                  2
# 9   28/10/2023 12:36                                  1
# 10  28/10/2023 12:37                                  2
# 11  28/10/2023 12:38                                  3
# 12  28/10/2023 12:39                                  2
# 13  28/10/2023 12:40                                  4
# 14  28/10/2023 12:41                                  4
# 15  28/10/2023 12:41                                  2
# ...

# %%
# Data Information
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Timestamp                                                          53 non-null     object
#  1   Kindly Rate your Sleep Quality ??                                  53 non-null     int64
#  2   How many times a week do you suffer headaches ???                  53 non-null     int64
#  3   How would you rate you academic performance ??????                 53 non-null     int64
#  4   how would you rate your study load?                                53 non-null     int64
#  5   How many times a week you practice extracurricular activities ???  53 non-null     int64
#  6   How would you rate your stress levels?                             53 non-null     int64
# ...

# %%
dataset.head()
# Out:
#           Timestamp  Kindly Rate your Sleep Quality ??  \
# 0  27/10/2023 21:54                                  3
# 1  28/10/2023 12:24                                  4
# 2  28/10/2023 12:24                                  2
# 3  28/10/2023 12:26                                  3
# 4  28/10/2023 12:26                                  2
#
#    How many times a week do you suffer headaches ???  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#    How would you rate you academic performance ??????  \
# 0                                                  3
# 1                                                  2
# 2                                                  2
# 3                                                  3
# ...

# %%
dataset.rename(columns={'Kindly Rate your Sleep Quality ??':'Quality Sleep','How many times a week do you suffer headaches ???':'Headache','How would you rate you academic performance ??????' : 'Academic Performance','how would you rate your study load?' : 'Study Load','How many times a week you practice extracurricular activities ???' : 'Extracurricular Act','How would you rate your stress levels?' : 'Stress Level'}, inplace=True)

# %%
dataset.head()
# Out:
#           Timestamp  Quality Sleep  Headache  Academic Performance  \
# 0  27/10/2023 21:54              3         1                     3
# 1  28/10/2023 12:24              4         1                     2
# 2  28/10/2023 12:24              2         1                     2
# 3  28/10/2023 12:26              3         2                     3
# 4  28/10/2023 12:26              2         3                     1
#
#    Study Load  Extracurricular Act  Stress Level
# 0           4                    2             3
# 1           3                    3             2
# 2           1                    4             4
# 3           2                    3             3
# 4           5                    5             3

# %%
#Perbandingan
# Data pertama
data1 = _df_19['Stress Level']

# Data kedua
data2 = _df_19['Academic Performance']

# Plot histogram untuk data pertama
plt.hist(data1, bins=20, alpha=0.5, label='Stress Level')

# Plot histogram untuk data kedua
plt.hist(data2, bins=20, alpha=0.5, label='Academic Performance')

# Menambahkan judul plot
plt.title('Hasil histogram perbandingan')

# Menambahkan label sumbu x dan y
plt.xlabel('Stress Level')
plt.ylabel('Academic Performance')

# Menambahkan legenda
plt.legend()

# Menampilkan plot
plt.show()

# %%
plt.scatter(dataset['Quality Sleep'],dataset['Stress Level'])

# %%
plt.scatter(dataset['Quality Sleep'], dataset['Stress Level'], c=dataset['Academic Performance'])
plt.colorbar(label='Academic Performance')
plt.xlabel('Sleep Quality')
plt.ylabel('Stress Level')
plt.show()

# %%
plt.scatter(dataset['Headache'], dataset['Study Load'], c=dataset['Extracurricular Act'])
plt.colorbar(label='Extracurricular Act')
plt.xlabel('Headache')
plt.ylabel('Study Load')
plt.show()

# %%
dataset.dtypes
# Out:
# Timestamp               object
# Quality Sleep            int64
# Headache                 int64
# Academic Performance     int64
# Study Load               int64
# Extracurricular Act      int64
# Stress Level             int64
# dtype: object

# %%
X=dataset[['Quality Sleep','Stress Level']]
Y=dataset['Academic Performance']

# %%
X
# Out:
#     Quality Sleep  Stress Level
# 0               3             3
# 1               4             2
# 2               2             4
# 3               3             3
# 4               2             3
# 5               3             1
# 6               3             5
# 7               4             1
# 8               2             1
# 9               1             2
# 10              2             4
# 11              3             1
# 12              2             3
# 13              4             1
# 14              4             2
# 15              2             4
# 16              3             4
# 17              1             2
# 18              2             3
# 19              2             4
# 20              3             2
# 21              3             3
# 22              2             2
# 23              3             3
# 24              5             1
# 25              3             1
# 26              5             5
# 27              5             1
# ...

# %%
Y
# Out:
# 0     3
# 1     2
# 2     2
# 3     3
# 4     1
# 5     3
# 6     1
# 7     1
# 8     4
# 9     3
# 10    5
# 11    5
# 12    3
# 13    4
# 14    3
# 15    3
# 16    3
# 17    1
# 18    3
# 19    3
# 20    2
# 21    4
# 22    2
# 23    4
# 24    4
# 25    3
# 26    5
# 27    5
# 28    3
# 29    2
# 30    3
# 31    3
# 32    4
# 33    4
# 34    5
# 35    4
# 36    1
# 37    3
# 38    4
# 39    4
# 40    3
# 41    4
# 42    3
# 43    4
# 44    4
# 45    3
# 46    4
# 47    3
# 48    4
# 49    1
# 50    5
# 51    5
# 52    3
# Name: Academic Performance, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
len(X_train)
# Out:
# 37

# %%
len(X_test)
# Out:
# 16

# %%
X_train
# Out:
#     Quality Sleep  Stress Level
# 47              4             2
# 49              1             1
# 51              1             1
# 12              2             3
# 37              3             3
# 20              3             2
# 33              2             2
# 40              4             2
# 52              3             2
# 7               4             1
# 30              5             5
# 43              2             3
# 4               2             3
# 36              4             5
# 35              5             5
# 11              3             1
# 15              2             4
# 28              2             2
# 23              3             3
# 19              2             4
# 25              3             1
# 9               1             2
# 46              2             4
# 22              2             2
# 6               3             5
# 21              3             3
# 2               2             4
# 5               3             1
# ...

# %%
X_test
# Out:
#     Quality Sleep  Stress Level
# 16              3             4
# 31              5             4
# 29              3             1
# 41              4             5
# 48              3             3
# 44              5             5
# 50              5             3
# 18              2             3
# 34              4             2
# 38              3             1
# 42              4             4
# 17              1             2
# 45              4             4
# 14              4             2
# 26              5             5
# 39              3             3

# %%
Y_train
# Out:
# 47    3
# 49    1
# 51    5
# 12    3
# 37    3
# 20    2
# 33    4
# 40    3
# 52    3
# 7     1
# 30    3
# 43    4
# 4     1
# 36    1
# 35    4
# 11    5
# 15    3
# 28    3
# 23    4
# 19    3
# 25    3
# 9     3
# 46    4
# 22    2
# 6     1
# 21    4
# 2     2
# 5     3
# 10    5
# 3     3
# 1     2
# 27    5
# 24    4
# 32    4
# 8     4
# 0     3
# 13    4
# Name: Academic Performance, dtype: int64

# %%
Y_test
# Out:
# 16    3
# 31    3
# 29    2
# 41    4
# 48    4
# 44    4
# 50    5
# 18    3
# 34    5
# 38    4
# 42    3
# 17    1
# 45    3
# 14    3
# 26    5
# 39    4
# Name: Academic Performance, dtype: int64
